# %%
from ultralytics import YOLO
from ipynb.fs.full.Observer import CaptureConfiguration
import matplotlib.pyplot as plt

# %%
model = YOLO("diceWatcher.pt")

# %%
print("Building Harmony Machine")
cc = CaptureConfiguration()
# Out:
# Building Harmony Machine

# %%
diceImage = cc.capture()['Dice']
plt.imshow(diceImage)

# %%
plt.imshow(model(diceImage)[0].plot())
# Out:
# 0: 384x640 1 three, 1 four, 4629.7ms
# Speed: 40.0ms preprocess, 4629.7ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
