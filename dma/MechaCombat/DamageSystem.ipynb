# %%
# %run ../quantumsystem.ipynb

# %%
class ArmorPlatingSystem(QuantumSystem.System):
    """ asdf """

# %%
class ArmorStructuralSystem(QuantumSystem.System):
    """ asdf """

# %%
class ArmorSystem(QuantumSystem.HyperSystem):
    systems = [ArmorPlatingSystem, ArmorStructuralSystem]

# %%
class EngineCriticalHitsSystem(QuantumSystem.System):
    """ asdf """

# %%
class FireControlCriticalHitsSystem(QuantumSystem.System):
    """ asdf """

# %%
class MPCriticalHitsSystem(QuantumSystem.System):
    """ asdf """

# %%
class WeaponsCriticalHitsSystem(QuantumSystem.System):
    """ asdf """

# %%
class CriticalHitsSystem(QuantumSystem.HyperSystem):
    systems = [EngineCriticalHitsSystem, FireControlCriticalHitsSystem, MPCriticalHitsSystem, WeaponsCriticalHitsSystem]

# %%
class UnitDamageSystem(QuantumSystem.HyperSystem):
    systems = [ArmorSystem, CriticalHitsSystem]

# %%
qs.reset()
UnitDamageSystem.build_system("foo", [["9", "7"], ["1", "4", "5", "6"]])
qs.render()
